# %% [markdown]
# <a href="https://colab.research.google.com/github/seadreamjj/danmu-ID/blob/main/%E7%8C%AB%E8%80%B3%E9%99%90%E5%85%8D%E5%BC%B9%E5%B9%95%E8%AE%A1%E7%AE%97.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 输出url

# %%
import requests
import re
import pandas as pd

# 输入剧集地址
drama_id = 'https://www.missevan.com/mdrama/78795'

# 构建 URL
drama_url = 'http://www.missevan.com/dramaapi/getdrama?drama_id='
url = drama_url + drama_id.split("/")[4]

# 请求剧集数据
drama_result = requests.get(url).text

# 使用正则表达式提取 sound_id
pattern1 = re.compile(r'"sound_id":(\d+),')  # 提取 sound_id
sound_ids = re.findall(pattern1, drama_result)

sound_url = 'http://www.missevan.com/sound/getdm?soundid='
dm1 = pd.DataFrame()

# 循环处理每个 sound_id，获取弹幕信息
for i in range(len(sound_ids)):
    url = sound_url + sound_ids[i]
    sound_result = requests.get(url).text

    # 提取弹幕内容
    pattern3 = re.compile(r'p="(.+?)"')
    dm = re.findall(pattern3, sound_result)


# 打印 DataFrame
print(dm)
# Out:
# ['821.00,1,25,16777215,1728986025,160,5022775,264076300', '953.00,1,25,16777215,1728985981,160,9024363,264076279', '1055.98,1,25,16777215,1728985848,160,11332526,264076226', '718.97,1,25,16777215,1728985535,160,28476436,264076079', '814.00,1,25,16777215,1728985175,160,12016971,264075869', '756.00,1,25,16777215,1728985118,160,12016971,264075844', '718.10,1,25,16777215,1728985011,160,28476436,264075777', '363.60,1,25,16777215,1728984657,160,28476436,264075579', '1078.00,1,25,16777215,1728984164,160,2848071,264075297', '807.00,1,25,16777215,1728983887,160,23276346,264075158', '743.00,1,25,16777215,1728983733,160,23276346,264075092', '869.00,1,25,16777215,1728983731,160,11899014,264075091', '677.00,1,25,16777215,1728983649,160,23276346,264075039', '639.00,1,25,16777215,1728983590,160,23276346,264075009', '742.00,1,25,16777215,1728983578,160,4649965,264075000', '886.00,1,25,16777215,1728983327,160,4649965,264074823', '456.00,1,25,16777215,1728983318,160,11899014,264074816', '812.00,1,25,16777215,1728983253,160,4649965,264074779', '629.00,1,25,16777215,1728983069,160,4649965,264074675', '592.00,1,25,16777215,1728983033,160,4649965,264074652', '566.00,1,25,16777215,1728983000,160,4649965,264074627', '553.00,1,25,16777215,1728982957,160,4649965,264074614', '457.00,1,25,16777215,1728982862,160,4649965,264074569', '823.00,1,25,16777215,1728982296,160,25505363,264074346', '612.95,1,25,16777215,1728982122,160,30060611,264074282', '604.14,1,25,16777215,1728982113,160,30060611,264074276', '590.64,1,25,16777215,1728982100,160,30060611,264074270', '1077.72,1,25,16777215,1728981447,160,25037905,264074017', '921.62,1,25,16777215,1728981291,160,25037905,264073955', '909.22,1,25,16777215,1728981279,160,25037905,264073949', '221.00,1,25,16777215,1728980997,160,24827602,264073814', '838.00,1,25,16777215,1728980728,160,24669934,264073677', '757.00,1,25,16777215,1728980702,160,4614548,264073664', '580.55,1,25,16777215,1728980653,160,4660361,264073645', '723.00,1,25,16777215,1728980549,160,4614548,264073602', '1059.92,1,25,16777215,1728980442,160,27659575,264073547', '27.64,1,25,16777215,1728980381,160,25037905,264073520', '23.04,1,25,16777215,1728980376,160,25037905,264073517', '985.42,1,25,16777215,1728980368,160,27659575,264073511', '955.42,1,25,16777215,1728980338,160,27659575,264073496', '906.12,1,25,16777215,1728980289,160,27659575,264073460', '607.00,1,25,16777215,1728980262,160,4614548,264073442', '389.37,1,25,16777215,1728980260,160,4660361,264073440', '818.81,1,25,16777215,1728980186,160,27659575,264073400', '591.00,1,25,16777215,1728980154,160,4614548,264073381', '622.00,1,25,16777215,1728980041,160,13087895,264073325', '559.00,1,25,16777215,1728980035,160,4614548,264073322', '570.00,1,25,16777215,1728979989,160,13087895,264073301', '22.52,1,25,16777215,1728979867,160,4660361,264073249', '1.23,1,25,16777215,1728979853,160,3998618,264073243', '805.01,1,25,16777215,1728979813,160,21517206,264073229', '474.00,1,25,16777215,1728979795,160,4614548,264073216', '858.00,1,25,16777215,1728979476,160,7145075,264073086', '726.82,1,25,16777215,1728979460,160,21517206,264073079', '727.00,1,25,16777215,1728979326,160,7145075,264073022', '712.00,1,25,16777215,1728979310,160,7145075,264073018', '656.00,1,25,16777215,1728979254,160,7145075,264072996', '275.00,1,25,16777215,1728979203,160,4614548,264072980', '630.00,1,25,16777215,1728979188,160,7145075,264072975', '1076.25,1,25,16777215,1728979177,160,25223491,264072968', '1061.15,1,25,16777215,1728979162,160,25223491,264072960', '992.93,1,25,16777215,1728979094,160,25223491,264072937', '980.43,1,25,16777215,1728979081,160,25223491,264072935', '974.25,1,25,16777215,1728979075,160,25223491,264072931', '954.18,1,25,16777215,1728979055,160,25223491,264072925', '947.85,1,25,16777215,1728979049,160,25223491,264072923', '937.35,1,25,16777215,1728979038,160,25223491,264072916', '862.39,1,25,16777215,1728979024,160,8163887,264072904', '902.73,1,25,16777215,1728979004,160,25223491,264072890', '895.87,1,25,16777215,17 ...

# %% [markdown]
# 具体分析弹幕内容

# %%
import pandas as pd
import requests
import re

# 输入剧集地址
drama_id = 'https://www.missevan.com/mdrama/78795'

# 构建 URL
drama_url = 'http://www.missevan.com/dramaapi/getdrama?drama_id='
url = drama_url + drama_id.split("/")[4]

# 请求剧集数据
drama_result = requests.get(url).text

# 使用正则表达式提取 sound_id
pattern1 = re.compile(r'"sound_id":(\d+),')  # 提取 sound_id
sound_ids = re.findall(pattern1, drama_result)

sound_url = 'http://www.missevan.com/sound/getdm?soundid='
dm1 = pd.DataFrame()

# 循环处理每个 sound_id，获取弹幕信息
for i in range(len(sound_ids)):
    url = sound_url + sound_ids[i]
    sound_result = requests.get(url).text

    # 提取弹幕内容
    pattern3 = re.compile(r'p="(.+?)"')
    dm = re.findall(pattern3, sound_result)

    # 将弹幕数据分割为具体字段
    dm_split = [d.split(',') for d in dm]

    # 将结果存储到 DataFrame 中
    dm_temp = pd.DataFrame(dm_split, columns=['time', 'type', 'size', 'color', 'timestamp', 'misc', 'user_id', 'dm_id'])

    # 合并数据
    if i == 0:
        dm1 = dm_temp
    else:
        dm1 = pd.concat([dm1, dm_temp], ignore_index=True)

# 打印 DataFrame 结果
print(dm1)
# Out:
#          time type size     color   timestamp misc   user_id      dm_id
# 0        1.00    1   25  16777215  1728983426  160   3579468  264074893
# 1      201.00    1   25  16777215  1728963012  160   5110674  264065882
# 2      177.00    1   25  16777215  1728962989  160   5110674  264065873
# 3       64.28    1   25  16777215  1728959142  160  26371595  264064414
# 4       27.00    1   25  16777215  1728916397  160   9130101  264050746
# ...       ...  ...  ...       ...         ...  ...       ...        ...
# 46572  573.08    1   25  16777215  1728912967   80  18166771  264047185
# 46573  756.00    1   25  16777215  1728912926   80  25749299  264047144
# 46574  807.00    1   25  16777215  1728912848   80   7145075  264047059
# 46575  610.00    1   25  16777215  1728912781   80  25749299  264046984
# 46576  699.02    1   25  16777215  1728912759   80   7020118  264046964
#
# [46577 rows x 8 columns]

# %%
# 检查 'misc' 字段的唯一值
print(dm1['misc'].unique())

# 查看 'misc' 与其他字段的关联，比如 'type' 或 'size'
print(dm1[['misc', 'type', 'size']].head())
# Out:
# ['160' '90' '80']
#   misc type size
# 0  160    1   25
# 1  160    1   25
# 2  160    1   25
# 3  160    1   25
# 4  160    1   25

# %%
import pandas as pd
import requests
import re

# 输入剧集地址
drama_id = 'https://www.missevan.com/mdrama/78795'

# 构建 URL
drama_url = 'http://www.missevan.com/dramaapi/getdrama?drama_id='
url = drama_url + drama_id.split("/")[4]

# 请求剧集数据
drama_result = requests.get(url).text

# 使用正则表达式提取 sound_id
pattern1 = re.compile(r'"sound_id":(\d+),')  # 提取 sound_id
sound_ids = re.findall(pattern1, drama_result)

sound_url = 'http://www.missevan.com/sound/getdm?soundid='
dm1 = pd.DataFrame()

# 循环处理每个 sound_id，获取弹幕信息
for i in range(len(sound_ids)):
    url = sound_url + sound_ids[i]
    sound_result = requests.get(url).text

    # 提取弹幕内容
    pattern3 = re.compile(r'p="(.+?)"')
    dm = re.findall(pattern3, sound_result)

    # 将弹幕数据分割为具体字段
    dm_split = [d.split(',') for d in dm]

    # 将结果存储到 DataFrame 中
    dm_temp = pd.DataFrame(dm_split, columns=['time', 'type', 'size', 'color', 'timestamp', 'misc', 'user_id', 'dm_id'])

    # 合并数据
    if i == 0:
        dm1 = dm_temp
    else:
        dm1 = pd.concat([dm1, dm_temp], ignore_index=True)

# 查看 'misc' 字段的唯一值
unique_type_values = dm1['type'].unique()
print("所有的 type 值为：")
print(unique_type_values)

# 查看 'misc' 与其他字段的关系
print("type 字段与 misc、size 等字段的关系：")
print(dm1[[ 'type', 'misc','size', 'color', 'user_id']].drop_duplicates().head())

# 可以对 'misc' 进行分组并统计不同 'misc' 值下其他字段的分布
print("\n'misc' 字段与 'type' 的关联统计：")
color_type_group = dm1.groupby(['type', 'color']).size()
print(color_type_group)
# Out:
# 所有的 type 值为：
# ['1' '4' '5']
# type 字段与 misc、size 等字段的关系：
#   type misc size     color   user_id
# 0    1  160   25  16777215   3579468
# 1    1  160   25  16777215   5110674
# 3    1  160   25  16777215  26371595
# 4    1  160   25  16777215   9130101
# 5    1  160   25  16777215    202916
#
# 'misc' 字段与 'type' 的关联统计：
# type  color
# 1     11979531        1
#       13306769        1
#       13753867        7
#       13943049        1
#       14145794        1
#       14345995        2
#       14345996        1
#       14803717        2
#       15526120        1
#       15853322        1
#       16777215    42595
#       1819116         1
#       5154777         1
#       7133923         1
#       7136193         7
#       7957731         2
# 4     10723793       35
#       10736027      136
#       11167563       50
#       11307935        1
#       11457741     1732
#       11784875       15
#       12114933      221
#       12365795      323
#       13034231       16
#       13155813       20
#       13483181        4
#       13617062       83
#       14718931        5
#       14928639        3
#       15716785       64
#       16766712        4
#       16767967      156
#       16768699      669
#       16776400       13
#       16777215       39
#       2327666         7
#       4691908        10
#       5029545       308
#       7630814         8
#       8551917        14
# 5     11735247        5
#       12328379       20
#       13765606       20
#       14233648        1
#       15522721        4
#       16711680        1
#       4854483        15
#       6441130         1
#       7136193         1
# dtype: int64

# %% [markdown]
# 台风眼限免ID计算（7.3 13.12）

# %%
import requests
import re
import pandas as pd
from datetime import datetime, timezone, timedelta

# 输入剧集地址
drama_id = 'https://www.missevan.com/mdrama/68664'

# 构建 URL
drama_url = 'http://www.missevan.com/dramaapi/getdrama?drama_id='
url = drama_url + drama_id.split("/")[4]

# 请求剧集数据
drama_result = requests.get(url).text

# 使用正则表达式提取 sound_id 和 pay_type
pattern1 = re.compile(r'"sound_id":(\d+),')  # 提取 sound_id
pattern2 = re.compile(r'"need_pay":(\d+),')  # 提取付费状态 need_pay
sound_id = re.findall(pattern1, drama_result)
pay_type = re.findall(pattern2, drama_result)

# 去掉第一个非付费项
pay_type = pay_type[1:]

# 创建 DataFrame
drama = pd.DataFrame({'sound_id': sound_id, 'pay_type': pay_type})

# 筛选付费 sound_id
sound_id = list(drama['sound_id'][drama['pay_type'] == '1'])

sound_url = 'http://www.missevan.com/sound/getdm?soundid='
dm1 = pd.DataFrame()

# 循环处理每个 sound_id，获取弹幕信息
for i in range(len(sound_id)):
    url = sound_url + sound_id[i]
    sound_result = requests.get(url).text

    # 提取弹幕内容
    pattern3 = re.compile(r'p="(.+?)"')
    dm = re.findall(pattern3, sound_result)

    # 将弹幕数据存储到 DataFrame
    dm_temp = pd.DataFrame({'dm': dm})
    dms_split = dm_temp['dm'].str.split('>', expand=True)[0]
    uid = dms_split.str.split(',', expand=True)[6]
    send_time = dms_split.str.split(',', expand=True)[4]  # 获取发送时间（时间戳）

    # 添加用户 ID 和发送时间到 DataFrame
    dm_temp['uid'] = uid
    dm_temp['send_time'] = send_time

    # 合并数据，使用 pd.concat() 替代 append()
    if i == 0:
        dm1 = dm_temp
    else:
        dm1 = pd.concat([dm1, dm_temp], ignore_index=True)

# 设置时间阈值（2024年7月3日13点12分）
threshold_time = (datetime(2024, 7, 3, 13, 12, 0, tzinfo=timezone.utc)- timedelta(hours=8)).timestamp()

# 提取在指定时间之后的 uid
valid_uids = set()

for index, row in dm1.iterrows():
    uid = row['uid']
    timestamp = int(row['send_time'])

    # 检查发送时间是否在阈值之后
    if timestamp >= threshold_time:
        valid_uids.add(uid)

# 输出去重后的用户 ID 数量
print("台风眼2在2024年7月3日13点12分以后的弹幕用户 ID 去重数量:", len(valid_uids))
# Out:
# 台风眼2在2024年7月3日13点12分以后的弹幕用户 ID 去重数量: 4974

# %% [markdown]
# 换另一个方法计算台风眼

# %%
import requests
import re
import pandas as pd
from datetime import datetime, timezone, timedelta

# 输入剧集地址
drama_id = 'https://www.missevan.com/mdrama/68664'

# 构建 URL
drama_url = 'http://www.missevan.com/dramaapi/getdrama?drama_id='
url = drama_url + drama_id.split("/")[4]

# 请求剧集数据
drama_result = requests.get(url).text

# 使用正则表达式提取 sound_id 和 pay_type
pattern1 = re.compile(r'"sound_id":(\d+),')  # 提取 sound_id
pattern2 = re.compile(r'"need_pay":(\d+),')  # 提取付费状态 need_pay
sound_id = re.findall(pattern1, drama_result)
pay_type = re.findall(pattern2, drama_result)

# 去掉第一个非付费项
pay_type = pay_type[1:]

# 创建 DataFrame
drama = pd.DataFrame({'sound_id': sound_id, 'pay_type': pay_type})

# 筛选付费 sound_id
sound_id = list(drama['sound_id'][drama['pay_type'] == '1'])

sound_url = 'http://www.missevan.com/sound/getdm?soundid='
dm1 = pd.DataFrame()

# 设置时间阈值（2024年7月3日13点12分）
threshold_time = (datetime(2024, 7, 3, 13, 12, 0, tzinfo=timezone.utc) - timedelta(hours=8)).timestamp()

# 存储第一集和第二集以后的用户 ID
valid_uids_first_episode = set()
valid_uids_after_second_episode = set()

# 循环处理每个 sound_id，获取弹幕信息
for i in range(len(sound_id)):
    url = sound_url + sound_id[i]
    sound_result = requests.get(url).text

    # 提取弹幕内容
    pattern3 = re.compile(r'p="(.+?)"')
    dm = re.findall(pattern3, sound_result)

    # 将弹幕数据存储到 DataFrame
    dm_temp = pd.DataFrame({'dm': dm})
    dms_split = dm_temp['dm'].str.split('>', expand=True)[0]
    uid = dms_split.str.split(',', expand=True)[6]
    send_time = dms_split.str.split(',', expand=True)[4]  # 获取发送时间（时间戳）

    # 添加用户 ID 和发送时间到 DataFrame
    dm_temp['uid'] = uid
    dm_temp['send_time'] = send_time

    # 合并数据，使用 pd.concat() 替代 append()
    if i == 0:  # 第一集
        for index, row in dm_temp.iterrows():
            timestamp = int(row['send_time'])
            if timestamp >= threshold_time:
                valid_uids_first_episode.add(row['uid'])
    elif i >= 1:  # 第二集及以后的集数
        for index, row in dm_temp.iterrows():
            valid_uids_after_second_episode.add(row['uid'])

# 合并去重用户 ID
merged_valid_uids = valid_uids_first_episode.union(valid_uids_after_second_episode)

# 输出去重后的用户 ID 数量
print("台风眼2在2024年7月3日13点12分以后的第一集和第二集以后的弹幕用户 ID 去重数量:", len(merged_valid_uids))
# Out:
# 台风眼2在2024年7月3日13点12分以后的第一集和第二集以后的弹幕用户 ID 去重数量: 4974

# %% [markdown]
# 惊封2上去除限免值（一周）

# %%
import requests
import re
import pandas as pd
from datetime import datetime, timezone, timedelta

# 输入剧集地址
drama_id = 'https://www.missevan.com/mdrama/71605'

# 构建 URL
drama_url = 'http://www.missevan.com/dramaapi/getdrama?drama_id='
url = drama_url + drama_id.split("/")[4]

# 请求剧集数据
drama_result = requests.get(url).text

# 使用正则表达式提取 sound_id 和 pay_type
pattern1 = re.compile(r'"sound_id":(\d+),')  # 提取 sound_id
pattern2 = re.compile(r'"need_pay":(\d+),')  # 提取付费状态 need_pay
sound_id = re.findall(pattern1, drama_result)
pay_type = re.findall(pattern2, drama_result)

# 去掉第一个非付费项
pay_type = pay_type[1:]

# 创建 DataFrame
drama = pd.DataFrame({'sound_id': sound_id, 'pay_type': pay_type})

# 筛选付费 sound_id
sound_id = list(drama['sound_id'][drama['pay_type'] == '1'])

sound_url = 'http://www.missevan.com/sound/getdm?soundid='
dm1 = pd.DataFrame()

# 循环处理每个 sound_id，获取弹幕信息
for i in range(len(sound_id)):
    url = sound_url + sound_id[i]
    sound_result = requests.get(url).text

    # 提取弹幕内容
    pattern3 = re.compile(r'p="(.+?)"')
    dm = re.findall(pattern3, sound_result)

    # 将弹幕数据存储到 DataFrame
    dm_temp = pd.DataFrame({'dm': dm})
    dms_split = dm_temp['dm'].str.split('>', expand=True)[0]
    uid = dms_split.str.split(',', expand=True)[6]
    send_time = dms_split.str.split(',', expand=True)[4]  # 获取发送时间（时间戳）

    # 添加用户 ID 和发送时间到 DataFrame
    dm_temp['uid'] = uid
    dm_temp['send_time'] = send_time

    # 合并数据，使用 pd.concat() 替代 append()
    if i == 0:
        dm1 = dm_temp
    else:
        dm1 = pd.concat([dm1, dm_temp], ignore_index=True)

# 设置时间阈值（2024年1月10日10点00分）
threshold_time = (datetime(2024, 1, 10, 10, 0, 0, tzinfo=timezone.utc) - timedelta(hours=8)).timestamp()


# 提取在指定时间之后的 uid
valid_uids = set()

for index, row in dm1.iterrows():
    uid = row['uid']
    timestamp = int(row['send_time'])

    # 检查发送时间是否在阈值之后
    if timestamp >= threshold_time:
        valid_uids.add(uid)

# 输出去重后的用户 ID 数量
print("惊封2上在2024年1月10日10点以后的弹幕用户 ID 去重数量:", len(valid_uids))
# Out:
# 惊封2上在2024年1月10日10点以后的弹幕用户 ID 去重数量: 18052

# %% [markdown]
# 百万up2限免两周

# %%
import requests
import re
import pandas as pd
from datetime import datetime, timezone, timedelta

# 输入剧集地址
drama_id = 'https://www.missevan.com/mdrama/72987'

# 构建 URL
drama_url = 'http://www.missevan.com/dramaapi/getdrama?drama_id='
url = drama_url + drama_id.split("/")[4]

# 请求剧集数据
drama_result = requests.get(url).text

# 使用正则表达式提取 sound_id 和 pay_type
pattern1 = re.compile(r'"sound_id":(\d+),')  # 提取 sound_id
pattern2 = re.compile(r'"need_pay":(\d+),')  # 提取付费状态 need_pay
sound_id = re.findall(pattern1, drama_result)
pay_type = re.findall(pattern2, drama_result)

# 去掉第一个非付费项
pay_type = pay_type[1:]

# 创建 DataFrame
drama = pd.DataFrame({'sound_id': sound_id, 'pay_type': pay_type})

# 筛选付费 sound_id
sound_id = list(drama['sound_id'][drama['pay_type'] == '1'])

sound_url = 'http://www.missevan.com/sound/getdm?soundid='
dm1 = pd.DataFrame()

# 循环处理每个 sound_id，获取弹幕信息
for i in range(len(sound_id)):
    url = sound_url + sound_id[i]
    sound_result = requests.get(url).text

    # 提取弹幕内容
    pattern3 = re.compile(r'p="(.+?)"')
    dm = re.findall(pattern3, sound_result)

    # 将弹幕数据存储到 DataFrame
    dm_temp = pd.DataFrame({'dm': dm})
    dms_split = dm_temp['dm'].str.split('>', expand=True)[0]
    uid = dms_split.str.split(',', expand=True)[6]
    send_time = dms_split.str.split(',', expand=True)[4]  # 获取发送时间（时间戳）

    # 添加用户 ID 和发送时间到 DataFrame
    dm_temp['uid'] = uid
    dm_temp['send_time'] = send_time

    # 合并数据，使用 pd.concat() 替代 append()
    if i == 0:
        dm1 = dm_temp
    else:
        dm1 = pd.concat([dm1, dm_temp], ignore_index=True)

# 设置时间阈值（2024年3月10日11点52分）
threshold_time = (datetime(2024, 3, 10, 11, 52, 0, tzinfo=timezone.utc)- timedelta(hours=8)).timestamp()

# 提取在指定时间之后的 uid
valid_uids = set()

for index, row in dm1.iterrows():
    uid = row['uid']
    timestamp = int(row['send_time'])

    # 检查发送时间是否在阈值之后
    if timestamp >= threshold_time:
        valid_uids.add(uid)

# 输出去重后的用户 ID 数量
print("百万up2在2024年3月10日11点52分以后的弹幕用户 ID 去重数量:", len(valid_uids))
# Out:
# 百万up2在2024年3月10日11点52分以后的弹幕用户 ID 去重数量: 6155

# %% [markdown]
# 百万up限免两周，第二周的第二集不应该被过滤，修正版：

# %%
import requests
import re
import pandas as pd
from datetime import datetime, timezone, timedelta

# 输入剧集地址
drama_id = 'https://www.missevan.com/mdrama/72987'

# 构建 URL
drama_url = 'http://www.missevan.com/dramaapi/getdrama?drama_id='
url = drama_url + drama_id.split("/")[4]

# 请求剧集数据
drama_result = requests.get(url).text

# 使用正则表达式提取 sound_id 和 pay_type
pattern1 = re.compile(r'"sound_id":(\d+),')  # 提取 sound_id
pattern2 = re.compile(r'"need_pay":(\d+),')  # 提取付费状态 need_pay
sound_id = re.findall(pattern1, drama_result)
pay_type = re.findall(pattern2, drama_result)

# 去掉第一个非付费项
pay_type = pay_type[1:]

# 创建 DataFrame
drama = pd.DataFrame({'sound_id': sound_id, 'pay_type': pay_type})

# 筛选付费 sound_id
sound_id = list(drama['sound_id'][drama['pay_type'] == '1'])

sound_url = 'http://www.missevan.com/sound/getdm?soundid='
dm1 = pd.DataFrame()

# 设置时间阈值（2024年3月10日11点52分）
threshold_time = (datetime(2024, 3, 10, 11, 52, 0, tzinfo=timezone.utc) - timedelta(hours=8)).timestamp()

# 存储第一集和第二集以后的用户 ID
valid_uids_first_episode = set()
valid_uids_after_second_episode = set()

# 循环处理每个 sound_id，获取弹幕信息
for i in range(len(sound_id)):
    url = sound_url + sound_id[i]
    sound_result = requests.get(url).text

    # 提取弹幕内容
    pattern3 = re.compile(r'p="(.+?)"')
    dm = re.findall(pattern3, sound_result)

    # 将弹幕数据存储到 DataFrame
    dm_temp = pd.DataFrame({'dm': dm})
    dms_split = dm_temp['dm'].str.split('>', expand=True)[0]
    uid = dms_split.str.split(',', expand=True)[6]
    send_time = dms_split.str.split(',', expand=True)[4]  # 获取发送时间（时间戳）

    # 添加用户 ID 和发送时间到 DataFrame
    dm_temp['uid'] = uid
    dm_temp['send_time'] = send_time

    # 合并数据，使用 pd.concat() 替代 append()
    if i == 0:  # 第一集
        for index, row in dm_temp.iterrows():
            timestamp = int(row['send_time'])
            if timestamp >= threshold_time:
                valid_uids_first_episode.add(row['uid'])
    elif i >= 1:  # 第二集及以后的集数
        for index, row in dm_temp.iterrows():
            valid_uids_after_second_episode.add(row['uid'])

# 合并去重用户 ID
merged_valid_uids = valid_uids_first_episode.union(valid_uids_after_second_episode)

# 输出去重后的用户 ID 数量
print("百万up2在2024年3月10日11点52分以后的第一集和第二集以后的弹幕用户 ID 去重数量:", len(merged_valid_uids))
# Out:
# 百万up2在2024年3月10日11点52分以后的第一集和第二集以后的弹幕用户 ID 去重数量: 6398
